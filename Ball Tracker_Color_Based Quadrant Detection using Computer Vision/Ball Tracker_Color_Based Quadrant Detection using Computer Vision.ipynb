# %%
import cv2
import numpy as np
import csv
import time


colors = {
    'yellow': ([20, 100, 100], [30, 255, 255]),
    'white': ([0, 0, 200], [180, 30, 255]),
    'orange': ([10, 100, 100], [20, 255, 255]),
    'blue': ([90, 100, 100], [130, 255, 255])
}


frame_width = 800 
frame_height = 600  

def set_quadrants(width, height):
    """Set quadrant boundaries based on frame dimensions."""
    return {
        3: (0, 0, width // 2, height // 2),          # Top-left
        4: (width // 2, 0, width // 2, height // 2),  # Top-right
        2: (0, height // 2, width // 2, height // 2), # Bottom-left
        1: (width // 2, height // 2, width // 2, height // 2)  # Bottom-right
    }

# Track ball positions to detect entry and exit events
ball_positions = {color: None for color in colors.keys()}

def detect_balls(frame, frame_time, csv_writer, quadrants):
    """
    Detects colored balls in the frame and logs their entry or exit from defined quadrants.

    Args:
    - frame: Input frame from the video
    - frame_time: Time of the current frame in the video
    - csv_writer: CSV writer object for logging events
    - quadrants: Dictionary defining quadrant boundaries

    Returns:
    - frame: Processed frame with visual annotations
    """
    hsv_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)
    
    for color_name, (lower_color, upper_color) in colors.items():
        lower_color = np.array(lower_color)
        upper_color = np.array(upper_color)
        mask = cv2.inRange(hsv_frame, lower_color, upper_color)
        contours, _ = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
        
        for contour in contours:
            area = cv2.contourArea(contour)
            if area > 100:
                x, y, w, h = cv2.boundingRect(contour)
                cv2.rectangle(frame, (x, y), (x + w, y + h), [int(c) for c in upper_color], 2)
                
                ball_center_x = x + w // 2
                ball_center_y = y + h // 2
                
                current_quadrant = None
                for quadrant_num, (qx, qy, qw, qh) in quadrants.items():
                    if qx <= ball_center_x < qx + qw and qy <= ball_center_y < qy + qh:
                        current_quadrant = quadrant_num
                        break
                
                if ball_positions[color_name] is None:
                    ball_positions[color_name] = current_quadrant
                
                previous_quadrant = ball_positions[color_name]
                if current_quadrant != previous_quadrant:
                    if previous_quadrant is not None:
                        event_type = "Exit"
                        print(f"Logging: {frame_time}, {previous_quadrant}, {color_name}, {event_type}")  # Debug print
                        csv_writer.writerow([frame_time, previous_quadrant, color_name, event_type])
                        cv2.putText(frame, f"Exit: {frame_time:.2f}", (ball_center_x, ball_center_y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, [int(c) for c in upper_color], 2)
                    
                    if current_quadrant is not None:
                        event_type = "Entry"
                        print(f"Logging: {frame_time}, {current_quadrant}, {color_name}, {event_type}")  # Debug print
                        csv_writer.writerow([frame_time, current_quadrant, color_name, event_type])
                        cv2.putText(frame, f"Entry: {frame_time:.2f}", (ball_center_x, ball_center_y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, [int(c) for c in upper_color], 2)
                
                ball_positions[color_name] = current_quadrant
    
    return frame

def process_video(video_path):
    """
    Processes the input video to detect colored balls and track their movement across defined quadrants.
    Saves the processed video and logs events to a CSV file.

    Args:
    - video_path: Path to the input video file
    """
    cap = cv2.VideoCapture(video_path)
    
    if not cap.isOpened():
        print("Error opening video file")
        return
    
    frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = cap.get(cv2.CAP_PROP_FPS)
    
    quadrants = set_quadrants(frame_width, frame_height)
    
    out_video_path = 'processed_video.mp4'
    out_video = cv2.VideoWriter(out_video_path, cv2.VideoWriter_fourcc(*'mp4v'), fps, (frame_width, frame_height))
    
    event_log_path = 'event_log.csv'
    with open(event_log_path, 'w', newline='') as event_log_file:
        csv_writer = csv.writer(event_log_file)
        csv_writer.writerow(['Time', 'Quadrant Number', 'Ball Colour', 'Event Type'])
        
        start_time = time.time()
        
        while cap.isOpened():
            ret, frame = cap.read()
            if not ret:
                break
            
            current_time = time.time()
            frame_time = current_time - start_time
            
            processed_frame = detect_balls(frame, frame_time, csv_writer, quadrants)
            out_video.write(processed_frame)
            
            cv2.imshow('Processed Video', processed_frame)
            if cv2.waitKey(1) & 0xFF == ord('q'):
                break
    
    cap.release()
    out_video.release()
    cv2.destroyAllWindows()
    
    print(f"Processed video saved as: {out_video_path}")
    print(f"Event log saved as: {event_log_path}")

if __name__ == "__main__":
    video_path = r"C:\Users\SHANMUKH\Downloads\AI Assignment video.mp4"
    process_video(video_path)
# Out:
# Logging: 0.05829453468322754, 1, white, Exit
# Logging: 0.05829453468322754, 4, white, Entry
# Logging: 0.05829453468322754, 1, blue, Exit
# Logging: 0.05829453468322754, 4, blue, Entry
# Logging: 0.25738978385925293, 4, white, Exit
# Logging: 0.25738978385925293, 1, white, Entry
# Logging: 0.25738978385925293, 1, white, Exit
# Logging: 0.25738978385925293, 4, white, Entry
# Logging: 0.25738978385925293, 4, white, Exit
# Logging: 0.25738978385925293, 3, white, Entry
# Logging: 0.25738978385925293, 3, white, Exit
# Logging: 0.25738978385925293, 4, white, Entry
# Logging: 0.25738978385925293, 4, blue, Exit
# Logging: 0.25738978385925293, 1, blue, Entry
# Logging: 0.25738978385925293, 1, blue, Exit
# Logging: 0.25738978385925293, 4, blue, Entry
# Logging: 0.3502371311187744, 4, white, Exit
# Logging: 0.3502371311187744, 1, white, Entry
# Logging: 0.3502371311187744, 1, white, Exit
# Logging: 0.3502371311187744, 4, white, Entry
# Logging: 0.3502371311187744, 4, blue, Exit
# Logging: 0.3502371311187744, 1, blue, Entry
# Logging: 0.3502371311187744, 1, blue, Exit
# Logging: 0.3502371311187744, 4, blue, Entry
# Logging: 0.46472597122192383, 4, white, Exit
# Logging: 0.46472597122192383, 1, white, Entry
# Logging: 0.46472597122192383, 1, white, Exit
# Logging: 0.46472597122192383, 4, white, Entry
# Logging: 0.46472597122192383, 4, blue, Exit
# Logging: 0.46472597122192383, 1, blue, Entry
# Logging: 0.46472597122192383, 1, blue, Exit
# Logging: 0.46472597122192383, 4, blue, Entry
# Logging: 0.5546789169311523, 4, white, Exit
# Logging: 0.5546789169311523, 1, white, Entry
# Logging: 0.5546789169311523, 1, white, Exit
# Logging: 0.5546789169311523, 4, white, Entry
# Logging: 0.5546789169311523, 4, blue, Exit
# Logging: 0.5546789169311523, 1, blue, Entry
# Logging: 0.5546789169311523, 1, blue, Exit
# Logging: 0.5546789169311523, 4, blue, Entry
# Logging: 0.6547362804412842, 4, white, Exit
# Logging: 0.6547362804412842, 1, white, Entry
# Logging: 0.6547362804412842, 1, white, Exit
# Logging: 0.6547362804412842, 4, white, Entry
# Logging: 0.6547362804412842, 4, blue, Exit
# Logging: 0.6547362804412842, 1, blue, Entry
# Logging: 0.6547362804412842, 1, blue, Exit
# Logging: 0.6547362804412842, 4, blue, Entry
# Logging: 0.7682080268859863, 4, white, Exit
# Logging: 0.7682080268859863, 1, white, Entry
# Logging: 0.7682080268859863, 1, white, Exit
# Logging: 0.7682080268859863, 4, white, Entry
# Logging: 0.7682080268859863, 4, blue, Exit
# Logging: 0.7682080268859863, 1, blue, Entry
# Logging: 0.7682080268859863, 1, blue, Exit
# Logging: 0.7682080268859863, 4, blue, Entry
# Logging: 0.8662703037261963, 4, white, Exit
# Logging: 0.8662703037261963, 1, white, Entry
# Logging: 0.8662703037261963, 1, white, Exit
# Logging: 0.8662703037261963, 4, white, Entry
# Logging: 0.8662703037261963, 4, blue, Exit
# Logging: 0.8662703037261963, 1, blue, Entry
# Logging: 0.8662703037261963, 1, blue, Exit
# Logging: 0.8662703037261963, 4, blue, Entry
# Logging: 0.944990873336792, 4, white, Exit
# Logging: 0.944990873336792, 1, white, Entry
# Logging: 0.944990873336792, 1, white, Exit
# Logging: 0.944990873336792, 4, white, Entry
# Logging: 0.944990873336792, 4, blue, Exit
# Logging: 0.944990873336792, 1, blue, Entry
# Logging: 0.944990873336792, 1, blue, Exit
# Logging: 0.944990873336792, 4, blue, Entry
# Logging: 1.0313422679901123, 4, white, Exit
# Logging: 1.0313422679901123, 1, white, Entry
# Logging: 1.0313422679901123, 1, white, Exit
# Logging: 1.0313422679901123, 4, white, Entry
# Logging: 1.0313422679901123, 4, white, Exit
# Logging: 1.0313422679901123, 3, white, Entry
# Logging: 1.0313422679901123, 3, white, Exit
# Logging: 1.0313422679901123, 4, white, Entry
# Logging: 1.0313422679901123, 4, white, Exit
# Logging: 1.0313422679901123, 3, white, Entry
# Logging: 1.0313422679901123, 4, blue, Exit
# Logging: 1.0313422679901123, 1, blue, Entry
# Logging: 1.0313422679901123, 1, blue, Exit
# Logging: 1.0313422679901123, 4, blue, Entry
# Logging: 1.1777353286743164, 3, white, Exit
# Logging: 1.1777353286743164, 1, white, Entry
# Logging: 1.1777353286743164, 1, white, Exit
# Logging: 1.1777353286743164, 4, white, Entry
# Logging: 1.1777353286743164, 4, white, Exit
# Logging: 1.1777353286743164, 3, white, Entry
# Logging: 1.1777353286743164, 4, blue, Exit
# Logging: 1.1777353286743164, 1, blue, Entry
# Logging: 1.1777353286743164, 1, blue, Exit
# Logging: 1.1777353286743164, 4, blue, Entry
# Logging: 1.3045275211334229, 3, white, Exit
# Logging: 1.3045275211334229, 1, white, Entry
# Logging: 1.3045275211334229, 1, white, Exit
# Logging: 1.3045275211334229, 4, white, Entry
# Logging: 1.3045275211334229, 4, white, Exit
# Logging: 1.3045275211334229, 3, white, Entry
# Logging: 1.3045275211334229, 4, blue, Exit
# Logging: 1.3045275211334229, 1, blue, Entry
# Logging: 1.3045275211334229, 1, blue, Exit
# Logging: 1.3045275211334229, 4, blue, Entry
# Logging: 1.4347002506256104, 3, white, Exit
# Logging: 1.4347002506256104, 1, white, Entry
# Logging: 1.4347002506256104, 1, white, Exit
# Logging: 1.4347002506256104, 4, white, Entry
# Logging: 1.4347002506256104, 4, white, Exit
# Logging: 1.4347002506256104, 3, white, Entry
# Logging: 1.4347002506256104, 4, blue, Exit
# Logging: 1.4347002506256104, 1, blue, Entry
# Logging: 1.4347002506256104, 1, blue, Exit
# Logging: 1.4347002506256104, 4, blue, Entry
# Logging: 1.522787094116211, 3, white, Exit
# Logging: 1.522787094116211, 1, white, Entry
# Logging: 1.522787094116211, 1, white, Exit
# Logging: 1.522787094116211, 4, white, Entry
# Logging: 1.522787094116211, 4, blue, Exit
# Logging: 1.522787094116211, 1, blue, Entry
# Logging: 1.522787094116211, 1, blue, Exit
# Logging: 1.522787094116211, 4, blue, Entry
# Logging: 1.6211905479431152, 4, white, Exit
# Logging: 1.6211905479431152, 1, white, Entry
# Logging: 1.6211905479431152, 1, white, Exit
# Logging: 1.6211905479431152, 4, white, Entry
# Logging: 1.6211905479431152, 4, blue, Exit
# Logging: 1.6211905479431152, 1, blue, Entry
# Logging: 1.6211905479431152, 1, blue, Exit
# Logging: 1.6211905479431152, 4, blue, Entry
# Logging: 1.711693286895752, 4, white, Exit
# Logging: 1.711693286895752, 1, white, Entry
# Logging: 1.711693286895752, 1, white, Exit
# Logging: 1.711693286895752, 4, white, Entry
# Logging: 1.711693286895752, 4, blue, Exit
# Logging: 1.711693286895752, 1, blue, Entry
# Logging: 1.711693286895752, 1, blue, Exit
# Logging: 1.711693286895752, 4, blue, Entry
# Logging: 1.8457224369049072, 4, white, Exit
# Logging: 1.8457224369049072, 1, white, Entry
# Logging: 1.8457224369049072, 1, white, Exit
# Logging: 1.8457224369049072, 4, white, Entry
# Logging: 1.8457224369049072, 4, blue, Exit
# Logging: 1.8457224369049072, 1, blue, Entry
# Logging: 1.8457224369049072, 1, blue, Exit
# Logging: 1.8457224369049072, 4, blue, Entry
# Logging: 1.9435241222381592, 4, white, Exit
# Logging: 1.9435241222381592, 1, white, Entry
# Logging: 1.9435241222381592, 1, white, Exit
# Logging: 1.9435241222381592, 4, white, Entry
# Logging: 1.9435241222381592, 4, blue, Exit
# Logging: 1.9435241222381592, 1, blue, Entry
# Logging: 1.9435241222381592, 1, blue, Exit
# Logging: 1.9435241222381592, 4, blue, Entry
# Logging: 2.041715621948242, 4, white, Exit
# Logging: 2.041715621948242, 1, white, Entry
# Logging: 2.041715621948242, 1, white, Exit
# Logging: 2.041715621948242, 4, white, Entry
# Logging: 2.041715621948242, 4, blue, Exit
# Logging: 2.041715621948242, 1, blue, Entry
# Logging: 2.041715621948242, 1, blue, Exit
# Logging: 2.041715621948242, 4, blue, Entry
# Logging: 2.137122392654419, 4, white, Exit
# Logging: 2.137122392654419, 1, white, Entry
# Logging: 2.137122392654419, 1, white, Exit
# Logging: 2.137122392654419, 4, white, Entry
# Logging: 2.137122392654419, 4, blue, Exit
# Logging: 2.137122392654419, 1, blue, Entry
# Logging: 2.137122392654419, 1, blue, Exit
# Logging: 2.137122392654419, 4, blue, Entry
# Logging: 2.219127893447876, 4, white, Exit
# Logging: 2.219127893447876, 1, white, Entry
# Logging: 2.219127893447876, 1, white, Exit
# Logging: 2.219127893447876, 4, white, Entry
# Logging: 2.219127893447876, 4, blue, Exit
# Logging: 2.219127893447876, 1, blue, Entry
# Logging: 2.219127893447876, 1, blue, Exit
# Logging: 2.219127893447876, 4, blue, Entry
# Logging: 2.3284482955932617, 4, white, Exit
# Logging: 2.3284482955932617, 1, white, Entry
# Logging: 2.3284482955932617, 1, white, Exit
# Logging: 2.3284482955932617, 4, white, Entry
# Logging: 2.3284482955932617, 4, blue, Exit
# Logging: 2.3284482955932617, 1, blue, Entry
# Logging: 2.3284482955932617, 1, blue, Exit
# Logging: 2.3284482955932617, 4, blue, Entry
# Logging: 2.422459125518799, 4, white, Exit
# Logging: 2.422459125518799, 1, white, Entry
# Logging: 2.422459125518799, 1, white, Exit
# Logging: 2.422459125518799, 4, white, Entry
# Logging: 2.422459125518799, 4, blue, Exit
# Logging: 2.422459125518799, 1, blue, Entry
# Logging: 2.422459125518799, 1, blue, Exit
# Logging: 2.422459125518799, 4, blue, Entry
# Logging: 2.518803596496582, 4, white, Exit
# Logging: 2.518803596496582, 1, white, Entry
# Logging: 2.518803596496582, 1, white, Exit
# Logging: 2.518803596496582, 4, white, Entry
# Logging: 2.518803596496582, 4, white, Exit
# Logging: 2.518803596496582, 3, white, Entry
# Logging: 2.518803596496582, 4, blue, Exit
# Logging: 2.518803596496582, 1, blue, Entry
# Logging: 2.518803596496582, 1, blue, Exit
# Logging: 2.518803596496582, 4, blue, Entry
# Logging: 2.6039304733276367, 3, white, Exit
# Logging: 2.6039304733276367, 1, white, Entry
# Logging: 2.6039304733276367, 1, white, Exit
# Logging: 2.6039304733276367, 4, white, Entry
# Logging: 2.6039304733276367, 4, blue, Exit
# Logging: 2.6039304733276367, 1, blue, Entry
# Logging: 2.6039304733276367, 1, blue, Exit
# Logging: 2.6039304733276367, 4, blue, Entry
# Logging: 2.700634002685547, 4, white, Exit
# Logging: 2.700634002685547, 1, white, Entry
# Logging: 2.700634002685547, 1, white, Exit
# Logging: 2.700634002685547, 4, white, Entry
# Logging: 2.700634002685547, 4, white, Exit
# Logging: 2.700634002685547, 3, white, Entry
# Logging: 2.700634002685547, 4, blue, Exit
# Logging: 2.700634002685547, 1, blue, Entry
# Logging: 2.700634002685547, 1, blue, Exit
# Logging: 2.700634002685547, 4, blue, Entry
# Logging: 2.7836685180664062, 3, white, Exit
# Logging: 2.7836685180664062, 1, white, Entry
# Logging: 2.7836685180664062, 1, white, Exit
# Logging: 2.7836685180664062, 4, white, Entry
# Logging: 2.7836685180664062, 4, white, Exit
# Logging: 2.7836685180664062, 3, white, Entry
# Logging: 2.7836685180664062, 4, blue, Exit
# Logging: 2.7836685180664062, 1, blue, Entry
# Logging: 2.7836685180664062, 1, blue, Exit
# Logging: 2.7836685180664062, 4, blue, Entry
# Logging: 2.8713204860687256, 3, white, Exit
# Logging: 2.8713204860687256, 1, white, Entry
# Logging: 2.8713204860687256, 1, white, Exit
# Logging: 2.8713204860687256, 4, white, Entry
# Logging: 2.8713204860687256, 4, white, Exit
# Logging: 2.8713204860687256, 3, white, Entry
# Logging: 2.8713204860687256, 4, blue, Exit
# Logging: 2.8713204860687256, 1, blue, Entry
# Logging: 2.8713204860687256, 1, blue, Exit
# Logging: 2.8713204860687256, 4, blue, Entry
# Logging: 2.9557793140411377, 3, white, Exit
# Logging: 2.9557793140411377, 1, white, Entry
# Logging: 2.9557793140411377, 1, white, Exit
# Logging: 2.9557793140411377, 4, white, Entry
# Logging: 2.9557793140411377, 4, blue, Exit
# Logging: 2.9557793140411377, 1, blue, Entry
# Logging: 2.9557793140411377, 1, blue, Exit
# Logging: 2.9557793140411377, 4, blue, Entry
# Logging: 3.0417091846466064, 4, white, Exit
# Logging: 3.0417091846466064, 1, white, Entry
# Logging: 3.0417091846466064, 1, white, Exit
# Logging: 3.0417091846466064, 4, white, Entry
# Logging: 3.0417091846466064, 4, white, Exit
# Logging: 3.0417091846466064, 3, white, Entry
# Logging: 3.0417091846466064, 4, blue, Exit
# Logging: 3.0417091846466064, 1, blue, Entry
# Logging: 3.0417091846466064, 1, blue, Exit
# Logging: 3.0417091846466064, 4, blue, Entry
# Logging: 3.136881113052368, 3, white, Exit
# Logging: 3.136881113052368, 1, white, Entry
# Logging: 3.136881113052368, 1, white, Exit
# Logging: 3.136881113052368, 4, white, Entry
# Logging: 3.136881113052368, 4, blue, Exit
# Logging: 3.136881113052368, 1, blue, Entry
# Logging: 3.136881113052368, 1, blue, Exit
# Logging: 3.136881113052368, 4, blue, Entry
# Logging: 3.2345690727233887, 4, white, Exit
# Logging: 3.2345690727233887, 1, white, Entry
# Logging: 3.2345690727233887, 1, white, Exit
# Logging: 3.2345690727233887, 4, white, Entry
# Logging: 3.2345690727233887, 4, white, Exit
# Logging: 3.2345690727233887, 3, white, Entry
# Logging: 3.2345690727233887, 4, blue, Exit
# Logging: 3.2345690727233887, 1, blue, Entry
# Logging: 3.2345690727233887, 1, blue, Exit
# Logging: 3.2345690727233887, 4, blue, Entry
# Logging: 3.3143811225891113, 3, white, Exit
# Logging: 3.3143811225891113, 1, white, Entry
# Logging: 3.3143811225891113, 1, white, Exit
# Logging: 3.3143811225891113, 4, white, Entry
# Logging: 3.3143811225891113, 4, white, Exit
# Logging: 3.3143811225891113, 3, white, Entry
# Logging: 3.3143811225891113, 4, blue, Exit
# Logging: 3.3143811225891113, 1, blue, Entry
# Logging: 3.3143811225891113, 1, blue, Exit
# Logging: 3.3143811225891113, 4, blue, Entry
# Logging: 3.3861501216888428, 3, white, Exit
# Logging: 3.3861501216888428, 1, white, Entry
# Logging: 3.3861501216888428, 1, white, Exit
# Logging: 3.3861501216888428, 4, white, Entry
# Logging: 3.3861501216888428, 4, white, Exit
# Logging: 3.3861501216888428, 3, white, Entry
# Logging: 3.3861501216888428, 4, blue, Exit
# Logging: 3.3861501216888428, 1, blue, Entry
# Logging: 3.3861501216888428, 1, blue, Exit
# Logging: 3.3861501216888428, 4, blue, Entry
# Logging: 3.466586112976074, 3, white, Exit
# Logging: 3.466586112976074, 1, white, Entry
# Logging: 3.466586112976074, 1, white, Exit
# Logging: 3.466586112976074, 4, white, Entry
# Logging: 3.466586112976074, 4, white, Exit
# Logging: 3.466586112976074, 3, white, Entry
# Logging: 3.466586112976074, 4, blue, Exit
# Logging: 3.466586112976074, 1, blue, Entry
# Logging: 3.466586112976074, 1, blue, Exit
# Logging: 3.466586112976074, 4, blue, Entry
# Logging: 3.556809663772583, 3, white, Exit
# Logging: 3.556809663772583, 1, white, Entry
# Logging: 3.556809663772583, 1, white, Exit
# Logging: 3.556809663772583, 4, white, Entry
# Logging: 3.556809663772583, 4, white, Exit
# Logging: 3.556809663772583, 3, white, Entry
# Logging: 3.556809663772583, 4, blue, Exit
# Logging: 3.556809663772583, 1, blue, Entry
# Logging: 3.556809663772583, 1, blue, Exit
# Logging: 3.556809663772583, 4, blue, Entry
# Logging: 3.6563446521759033, 3, white, Exit
# Logging: 3.6563446521759033, 1, white, Entry
# Logging: 3.6563446521759033, 1, white, Exit
# Logging: 3.6563446521759033, 4, white, Entry
# Logging: 3.6563446521759033, 4, white, Exit
# Logging: 3.6563446521759033, 3, white, Entry
# Logging: 3.6563446521759033, 4, blue, Exit
# Logging: 3.6563446521759033, 1, blue, Entry
# Logging: 3.6563446521759033, 1, blue, Exit
# Logging: 3.6563446521759033, 4, blue, Entry
# Logging: 3.7373597621917725, 3, white, Exit
# Logging: 3.7373597621917725, 1, white, Entry
# Logging: 3.7373597621917725, 1, white, Exit
# Logging: 3.7373597621917725, 4, white, Entry
# Logging: 3.7373597621917725, 4, white, Exit
# Logging: 3.7373597621917725, 3, white, Entry
# Logging: 3.7373597621917725, 4, blue, Exit
# Logging: 3.7373597621917725, 1, blue, Entry
# Logging: 3.7373597621917725, 1, blue, Exit
# Logging: 3.7373597621917725, 4, blue, Entry
# Logging: 3.8330740928649902, 3, white, Exit
# Logging: 3.8330740928649902, 1, white, Entry
# Logging: 3.8330740928649902, 1, white, Exit
# Logging: 3.8330740928649902, 4, white, Entry
# Logging: 3.8330740928649902, 4, blue, Exit
# Logging: 3.8330740928649902, 1, blue, Entry
# Logging: 3.8330740928649902, 1, blue, Exit
# Logging: 3.8330740928649902, 4, blue, Entry
# Logging: 3.9230332374572754, 4, white, Exit
# Logging: 3.9230332374572754, 1, white, Entry
# Logging: 3.9230332374572754, 1, white, Exit
# Logging: 3.9230332374572754, 4, white, Entry
# Logging: 3.9230332374572754, 4, white, Exit
# Logging: 3.9230332374572754, 3, white, Entry
# Logging: 3.9230332374572754, 4, blue, Exit
# Logging: 3.9230332374572754, 1, blue, Entry
# Logging: 3.9230332374572754, 1, blue, Exit
# Logging: 3.9230332374572754, 4, blue, Entry
# Logging: 4.014326810836792, 3, white, Exit
# Logging: 4.014326810836792, 1, white, Entry
# Logging: 4.014326810836792, 1, white, Exit
# Logging: 4.014326810836792, 4, white, Entry
# Logging: 4.014326810836792, 4, white, Exit
# Logging: 4.014326810836792, 3, white, Entry
# Logging: 4.014326810836792, 3, white, Exit
# Logging: 4.014326810836792, 4, white, Entry
# Logging: 4.014326810836792, 4, white, Exit
# Logging: 4.014326810836792, 3, white, Entry
# Logging: 4.014326810836792, 4, blue, Exit
# Logging: 4.014326810836792, 1, blue, Entry
# Logging: 4.014326810836792, 1, blue, Exit
# Logging: 4.014326810836792, 4, blue, Entry
# Logging: 4.101571798324585, 3, white, Exit
# Logging: 4.101571798324585, 1, white, Entry
# Logging: 4.101571798324585, 1, white, Exit
# Logging: 4.101571798324585, 4, white, Entry
# Logging: 4.101571798324585, 4, blue, Exit
# Logging: 4.101571798324585, 1, blue, Entry
# Logging: 4.101571798324585, 1, blue, Exit
# Logging: 4.101571798324585, 4, blue, Entry
# Logging: 4.188353538513184, 4, white, Exit
# Logging: 4.188353538513184, 1, white, Entry
# Logging: 4.188353538513184, 1, white, Exit
# Logging: 4.188353538513184, 4, white, Entry
# Logging: 4.188353538513184, 4, white, Exit
# Logging: 4.188353538513184, 3, white, Entry
# Logging: 4.188353538513184, 4, blue, Exit
# Logging: 4.188353538513184, 1, blue, Entry
# Logging: 4.188353538513184, 1, blue, Exit
# Logging: 4.188353538513184, 4, blue, Entry
# Logging: 4.286938667297363, 3, white, Exit
# Logging: 4.286938667297363, 1, white, Entry
# Logging: 4.286938667297363, 1, white, Exit
# Logging: 4.286938667297363, 4, white, Entry
# Logging: 4.286938667297363, 4, white, Exit
# Logging: 4.286938667297363, 3, white, Entry
# Logging: 4.286938667297363, 4, blue, Exit
# Logging: 4.286938667297363, 1, blue, Entry
# Logging: 4.286938667297363, 1, blue, Exit
# Logging: 4.286938667297363, 4, blue, Entry
# Logging: 4.370232820510864, 3, white, Exit
# Logging: 4.370232820510864, 1, white, Entry
# Logging: 4.370232820510864, 1, white, Exit
# Logging: 4.370232820510864, 4, white, Entry
# Logging: 4.370232820510864, 4, white, Exit
# Logging: 4.370232820510864, 3, white, Entry
# Logging: 4.370232820510864, 4, blue, Exit
# Logging: 4.370232820510864, 1, blue, Entry
# Logging: 4.370232820510864, 1, blue, Exit
# Logging: 4.370232820510864, 4, blue, Entry
# Logging: 4.451559543609619, 3, white, Exit
# Logging: 4.451559543609619, 1, white, Entry
# Logging: 4.451559543609619, 1, white, Exit
# Logging: 4.451559543609619, 4, white, Entry
# Logging: 4.451559543609619, 4, white, Exit
# Logging: 4.451559543609619, 3, white, Entry
# Logging: 4.451559543609619, 4, blue, Exit
# Logging: 4.451559543609619, 1, blue, Entry
# Logging: 4.451559543609619, 1, blue, Exit
# Logging: 4.451559543609619, 4, blue, Entry
# Logging: 4.550501108169556, 3, white, Exit
# Logging: 4.550501108169556, 1, white, Entry
# Logging: 4.550501108169556, 1, white, Exit
# Logging: 4.550501108169556, 4, white, Entry
# Logging: 4.550501108169556, 4, blue, Exit
# Logging: 4.550501108169556, 1, blue, Entry
# Logging: 4.550501108169556, 1, blue, Exit
# Logging: 4.550501108169556, 4, blue, Entry
# Logging: 4.630011558532715, 4, white, Exit
# Logging: 4.630011558532715, 1, white, Entry
# Logging: 4.630011558532715, 1, white, Exit
# Logging: 4.630011558532715, 4, white, Entry
# Logging: 4.630011558532715, 4, blue, Exit
# Logging: 4.630011558532715, 1, blue, Entry
# Logging: 4.630011558532715, 1, blue, Exit
# Logging: 4.630011558532715, 4, blue, Entry
# Logging: 4.71043586730957, 4, white, Exit
# Logging: 4.71043586730957, 1, white, Entry
# Logging: 4.71043586730957, 1, white, Exit
# Logging: 4.71043586730957, 4, white, Entry
# Logging: 4.71043586730957, 4, white, Exit
# Logging: 4.71043586730957, 3, white, Entry
# Logging: 4.71043586730957, 4, blue, Exit
# Logging: 4.71043586730957, 1, blue, Entry
# Logging: 4.71043586730957, 1, blue, Exit
# Logging: 4.71043586730957, 4, blue, Entry
# Logging: 4.7876951694488525, 3, white, Exit
# Logging: 4.7876951694488525, 1, white, Entry
# Logging: 4.7876951694488525, 1, white, Exit
# Logging: 4.7876951694488525, 4, white, Entry
# Logging: 4.7876951694488525, 4, white, Exit
# Logging: 4.7876951694488525, 3, white, Entry
# Logging: 4.7876951694488525, 4, blue, Exit
# Logging: 4.7876951694488525, 1, blue, Entry
# Logging: 4.7876951694488525, 1, blue, Exit
# Logging: 4.7876951694488525, 4, blue, Entry
# Logging: 4.864827394485474, 3, white, Exit
# Logging: 4.864827394485474, 1, white, Entry
# Logging: 4.864827394485474, 1, white, Exit
# Logging: 4.864827394485474, 4, white, Entry
# Logging: 4.864827394485474, 4, white, Exit
# Logging: 4.864827394485474, 3, white, Entry
# Logging: 4.864827394485474, 4, blue, Exit
# Logging: 4.864827394485474, 1, blue, Entry
# Logging: 4.864827394485474, 1, blue, Exit
# Logging: 4.864827394485474, 4, blue, Entry
# Logging: 4.944014310836792, 3, white, Exit
# Logging: 4.944014310836792, 1, white, Entry
# Logging: 4.944014310836792, 1, white, Exit
# Logging: 4.944014310836792, 4, white, Entry
# Logging: 4.944014310836792, 4, blue, Exit
# Logging: 4.944014310836792, 1, blue, Entry
# Logging: 4.944014310836792, 1, blue, Exit
# Logging: 4.944014310836792, 4, blue, Entry
# Logging: 5.030789613723755, 4, white, Exit
# Logging: 5.030789613723755, 1, white, Entry
# Logging: 5.030789613723755, 1, white, Exit
# Logging: 5.030789613723755, 4, white, Entry
# Logging: 5.030789613723755, 4, white, Exit
# Logging: 5.030789613723755, 3, white, Entry
# Logging: 5.030789613723755, 4, blue, Exit
# Logging: 5.030789613723755, 1, blue, Entry
# Logging: 5.030789613723755, 1, blue, Exit
# Logging: 5.030789613723755, 4, blue, Entry
# Logging: 5.105339050292969, 3, white, Exit
# Logging: 5.105339050292969, 1, white, Entry
# Logging: 5.105339050292969, 1, white, Exit
# Logging: 5.105339050292969, 4, white, Entry
# Logging: 5.105339050292969, 4, white, Exit
# Logging: 5.105339050292969, 3, white, Entry
# Logging: 5.105339050292969, 4, blue, Exit
# Logging: 5.105339050292969, 1, blue, Entry
# Logging: 5.105339050292969, 1, blue, Exit
# Logging: 5.105339050292969, 4, blue, Entry
# Logging: 5.182068586349487, 3, white, Exit
# Logging: 5.182068586349487, 1, white, Entry
# Logging: 5.182068586349487, 1, white, Exit
# Logging: 5.182068586349487, 4, white, Entry
# Logging: 5.182068586349487, 4, white, Exit
# Logging: 5.182068586349487, 3, white, Entry
# Logging: 5.182068586349487, 4, blue, Exit
# Logging: 5.182068586349487, 1, blue, Entry
# Logging: 5.182068586349487, 1, blue, Exit
# Logging: 5.182068586349487, 4, blue, Entry
# Logging: 5.267149209976196, 3, white, Exit
# Logging: 5.267149209976196, 1, white, Entry
# Logging: 5.267149209976196, 1, white, Exit
# Logging: 5.267149209976196, 4, white, Entry
# Logging: 5.267149209976196, 4, white, Exit
# Logging: 5.267149209976196, 3, white, Entry
# Logging: 5.267149209976196, 4, blue, Exit
# Logging: 5.267149209976196, 1, blue, Entry
# Logging: 5.267149209976196, 1, blue, Exit
# Logging: 5.267149209976196, 4, blue, Entry
# Logging: 5.3533525466918945, 3, white, Exit
# Logging: 5.3533525466918945, 1, white, Entry
# Logging: 5.3533525466918945, 1, white, Exit
# Logging: 5.3533525466918945, 4, white, Entry
# Logging: 5.3533525466918945, 4, blue, Exit
# Logging: 5.3533525466918945, 1, blue, Entry
# Logging: 5.3533525466918945, 1, blue, Exit
# Logging: 5.3533525466918945, 4, blue, Entry
# Logging: 5.430196046829224, 4, white, Exit
# Logging: 5.430196046829224, 1, white, Entry
# Logging: 5.430196046829224, 1, white, Exit
# Logging: 5.430196046829224, 4, white, Entry
# Logging: 5.430196046829224, 4, white, Exit
# Logging: 5.430196046829224, 3, white, Entry
# Logging: 5.430196046829224, 4, blue, Exit
# Logging: 5.430196046829224, 1, blue, Entry
# Logging: 5.430196046829224, 1, blue, Exit
# Logging: 5.430196046829224, 4, blue, Entry
# Logging: 5.518646240234375, 3, white, Exit
# Logging: 5.518646240234375, 1, white, Entry
# Logging: 5.518646240234375, 1, white, Exit
# Logging: 5.518646240234375, 4, white, Entry
# Logging: 5.518646240234375, 4, white, Exit
# Logging: 5.518646240234375, 3, white, Entry
# Logging: 5.518646240234375, 4, blue, Exit
# Logging: 5.518646240234375, 1, blue, Entry
# Logging: 5.518646240234375, 1, blue, Exit
# Logging: 5.518646240234375, 4, blue, Entry
# Logging: 5.611850738525391, 3, white, Exit
# Logging: 5.611850738525391, 1, white, Entry
# Logging: 5.611850738525391, 1, white, Exit
# Logging: 5.611850738525391, 4, white, Entry
# Logging: 5.611850738525391, 4, white, Exit
# Logging: 5.611850738525391, 3, white, Entry
# Logging: 5.611850738525391, 4, blue, Exit
# Logging: 5.611850738525391, 1, blue, Entry
# Logging: 5.611850738525391, 1, blue, Exit
# Logging: 5.611850738525391, 4, blue, Entry
# Logging: 5.705370664596558, 3, white, Exit
# Logging: 5.705370664596558, 1, white, Entry
# Logging: 5.705370664596558, 1, white, Exit
# Logging: 5.705370664596558, 4, white, Entry
# Logging: 5.705370664596558, 4, blue, Exit
# Logging: 5.705370664596558, 1, blue, Entry
# Logging: 5.705370664596558, 1, blue, Exit
# Logging: 5.705370664596558, 4, blue, Entry
# Logging: 5.811816215515137, 4, white, Exit
# Logging: 5.811816215515137, 1, white, Entry
# Logging: 5.811816215515137, 1, white, Exit
# Logging: 5.811816215515137, 4, white, Entry
# Logging: 5.811816215515137, 4, white, Exit
# Logging: 5.811816215515137, 3, white, Entry
# Logging: 5.811816215515137, 4, blue, Exit
# Logging: 5.811816215515137, 1, blue, Entry
# Logging: 5.811816215515137, 1, blue, Exit
# Logging: 5.811816215515137, 4, blue, Entry
# Logging: 5.898789644241333, 3, white, Exit
# Logging: 5.898789644241333, 1, white, Entry
# Logging: 5.898789644241333, 1, white, Exit
# Logging: 5.898789644241333, 4, white, Entry
# Logging: 5.898789644241333, 4, white, Exit
# Logging: 5.898789644241333, 3, white, Entry
# Logging: 5.898789644241333, 4, blue, Exit
# Logging: 5.898789644241333, 1, blue, Entry
# Logging: 5.898789644241333, 1, blue, Exit
# Logging: 5.898789644241333, 4, blue, Entry
# Logging: 5.983726263046265, 3, white, Exit
# Logging: 5.983726263046265, 1, white, Entry
# Logging: 5.983726263046265, 1, white, Exit
# Logging: 5.983726263046265, 4, white, Entry
# Logging: 5.983726263046265, 1, orange, Exit
# Logging: 5.983726263046265, 4, orange, Entry
# Logging: 5.983726263046265, 4, blue, Exit
# Logging: 5.983726263046265, 1, blue, Entry
# Logging: 5.983726263046265, 1, blue, Exit
# Logging: 5.983726263046265, 4, blue, Entry
# Logging: 6.070091009140015, 1, yellow, Exit
# Logging: 6.070091009140015, 4, yellow, Entry
# Logging: 6.070091009140015, 4, white, Exit
# Logging: 6.070091009140015, 1, white, Entry
# Logging: 6.070091009140015, 1, white, Exit
# Logging: 6.070091009140015, 4, white, Entry
# Logging: 6.070091009140015, 4, white, Exit
# Logging: 6.070091009140015, 3, white, Entry
# Logging: 6.070091009140015, 4, blue, Exit
# Logging: 6.070091009140015, 1, blue, Entry
# Logging: 6.070091009140015, 1, blue, Exit
# Logging: 6.070091009140015, 4, blue, Entry
# Logging: 6.149570465087891, 3, white, Exit
# Logging: 6.149570465087891, 1, white, Entry
# Logging: 6.149570465087891, 1, white, Exit
# Logging: 6.149570465087891, 4, white, Entry
# Logging: 6.149570465087891, 4, blue, Exit
# Logging: 6.149570465087891, 1, blue, Entry
# Logging: 6.149570465087891, 1, blue, Exit
# Logging: 6.149570465087891, 4, blue, Entry
# Logging: 6.221895933151245, 4, white, Exit
# Logging: 6.221895933151245, 1, white, Entry
# Logging: 6.221895933151245, 1, white, Exit
# Logging: 6.221895933151245, 4, white, Entry
# Logging: 6.221895933151245, 4, blue, Exit
# Logging: 6.221895933151245, 1, blue, Entry
# Logging: 6.221895933151245, 1, blue, Exit
# Logging: 6.221895933151245, 4, blue, Entry
# Logging: 6.303382635116577, 4, white, Exit
# Logging: 6.303382635116577, 1, white, Entry
# Logging: 6.303382635116577, 1, white, Exit
# Logging: 6.303382635116577, 4, white, Entry
# Logging: 6.303382635116577, 4, blue, Exit
# Logging: 6.303382635116577, 1, blue, Entry
# Logging: 6.303382635116577, 1, blue, Exit
# Logging: 6.303382635116577, 4, blue, Entry
# Logging: 6.384779930114746, 4, white, Exit
# Logging: 6.384779930114746, 1, white, Entry
# Logging: 6.384779930114746, 1, white, Exit
# Logging: 6.384779930114746, 4, white, Entry
# Logging: 6.384779930114746, 4, white, Exit
# Logging: 6.384779930114746, 3, white, Entry
# Logging: 6.384779930114746, 4, orange, Exit
# Logging: 6.384779930114746, 1, orange, Entry
# Logging: 6.384779930114746, 4, blue, Exit
# Logging: 6.384779930114746, 1, blue, Entry
# Logging: 6.384779930114746, 1, blue, Exit
# Logging: 6.384779930114746, 4, blue, Entry
# Logging: 6.464231252670288, 3, white, Exit
# Logging: 6.464231252670288, 1, white, Entry
# Logging: 6.464231252670288, 1, white, Exit
# Logging: 6.464231252670288, 4, white, Entry
# Logging: 6.464231252670288, 4, blue, Exit
# Logging: 6.464231252670288, 1, blue, Entry
# Logging: 6.464231252670288, 1, blue, Exit
# Logging: 6.464231252670288, 4, blue, Entry
# Logging: 6.551753997802734, 4, white, Exit
# Logging: 6.551753997802734, 1, white, Entry
# Logging: 6.551753997802734, 1, white, Exit
# Logging: 6.551753997802734, 4, white, Entry
# Logging: 6.551753997802734, 4, white, Exit
# Logging: 6.551753997802734, 3, white, Entry
# Logging: 6.551753997802734, 4, blue, Exit
# Logging: 6.551753997802734, 1, blue, Entry
# Logging: 6.551753997802734, 1, blue, Exit
# Logging: 6.551753997802734, 4, blue, Entry
# Logging: 6.639561891555786, 3, white, Exit
# Logging: 6.639561891555786, 1, white, Entry
# Logging: 6.639561891555786, 1, white, Exit
# Logging: 6.639561891555786, 4, white, Entry
# Logging: 6.639561891555786, 4, white, Exit
# Logging: 6.639561891555786, 3, white, Entry
# Logging: 6.639561891555786, 4, blue, Exit
# Logging: 6.639561891555786, 1, blue, Entry
# Logging: 6.639561891555786, 1, blue, Exit
# Logging: 6.639561891555786, 4, blue, Entry
# Logging: 6.7299275398254395, 3, white, Exit
# Logging: 6.7299275398254395, 1, white, Entry
# Logging: 6.7299275398254395, 1, white, Exit
# Logging: 6.7299275398254395, 4, white, Entry
# Logging: 6.7299275398254395, 4, blue, Exit
# Logging: 6.7299275398254395, 1, blue, Entry
# Logging: 6.7299275398254395, 1, blue, Exit
# Logging: 6.7299275398254395, 4, blue, Entry
# Logging: 6.808423757553101, 4, white, Exit
# Logging: 6.808423757553101, 1, white, Entry
# Logging: 6.808423757553101, 1, white, Exit
# Logging: 6.808423757553101, 4, white, Entry
# Logging: 6.808423757553101, 4, blue, Exit
# Logging: 6.808423757553101, 1, blue, Entry
# Logging: 6.808423757553101, 1, blue, Exit
# Logging: 6.808423757553101, 4, blue, Entry
# Logging: 6.886376857757568, 4, white, Exit
# Logging: 6.886376857757568, 1, white, Entry
# Logging: 6.886376857757568, 1, white, Exit
# Logging: 6.886376857757568, 4, white, Entry
# Logging: 6.886376857757568, 4, blue, Exit
# Logging: 6.886376857757568, 1, blue, Entry
# Logging: 6.886376857757568, 1, blue, Exit
# Logging: 6.886376857757568, 4, blue, Entry
# Logging: 6.952786445617676, 4, white, Exit
# Logging: 6.952786445617676, 1, white, Entry
# Logging: 6.952786445617676, 1, white, Exit
# Logging: 6.952786445617676, 4, white, Entry
# Logging: 6.952786445617676, 4, blue, Exit
# Logging: 6.952786445617676, 1, blue, Entry
# Logging: 6.952786445617676, 1, blue, Exit
# Logging: 6.952786445617676, 4, blue, Entry
# Logging: 7.037900924682617, 4, white, Exit
# Logging: 7.037900924682617, 1, white, Entry
# Logging: 7.037900924682617, 1, white, Exit
# Logging: 7.037900924682617, 4, white, Entry
# Logging: 7.037900924682617, 4, white, Exit
# Logging: 7.037900924682617, 3, white, Entry
# Logging: 7.037900924682617, 3, white, Exit
# Logging: 7.037900924682617, 4, white, Entry
# Logging: 7.037900924682617, 4, blue, Exit
# Logging: 7.037900924682617, 1, blue, Entry
# Logging: 7.037900924682617, 1, blue, Exit
# Logging: 7.037900924682617, 4, blue, Entry
# Logging: 7.115435361862183, 4, white, Exit
# Logging: 7.115435361862183, 1, white, Entry
# Logging: 7.115435361862183, 1, white, Exit
# Logging: 7.115435361862183, 4, white, Entry
# Logging: 7.115435361862183, 4, white, Exit
# Logging: 7.115435361862183, 3, white, Entry
# Logging: 7.115435361862183, 4, blue, Exit
# Logging: 7.115435361862183, 1, blue, Entry
# Logging: 7.115435361862183, 1, blue, Exit
# Logging: 7.115435361862183, 4, blue, Entry
# Logging: 7.183443069458008, 3, white, Exit
# Logging: 7.183443069458008, 1, white, Entry
# Logging: 7.183443069458008, 1, white, Exit
# Logging: 7.183443069458008, 4, white, Entry
# Logging: 7.183443069458008, 4, white, Exit
# Logging: 7.183443069458008, 3, white, Entry
# Logging: 7.183443069458008, 4, blue, Exit
# Logging: 7.183443069458008, 1, blue, Entry
# Logging: 7.183443069458008, 1, blue, Exit
# Logging: 7.183443069458008, 4, blue, Entry
# Logging: 7.253962993621826, 3, white, Exit
# Logging: 7.253962993621826, 1, white, Entry
# Logging: 7.253962993621826, 1, white, Exit
# Logging: 7.253962993621826, 4, white, Entry
# Logging: 7.253962993621826, 4, white, Exit
# Logging: 7.253962993621826, 3, white, Entry
# Logging: 7.253962993621826, 4, blue, Exit
# Logging: 7.253962993621826, 1, blue, Entry
# Logging: 7.253962993621826, 1, blue, Exit
# Logging: 7.253962993621826, 4, blue, Entry
# Logging: 7.33448338508606, 3, white, Exit
# Logging: 7.33448338508606, 1, white, Entry
# Logging: 7.33448338508606, 1, white, Exit
# Logging: 7.33448338508606, 4, white, Entry
# Logging: 7.33448338508606, 4, white, Exit
# Logging: 7.33448338508606, 3, white, Entry
# Logging: 7.33448338508606, 4, blue, Exit
# Logging: 7.33448338508606, 1, blue, Entry
# Logging: 7.33448338508606, 1, blue, Exit
# Logging: 7.33448338508606, 4, blue, Entry
# Logging: 7.403487920761108, 3, white, Exit
# Logging: 7.403487920761108, 1, white, Entry
# Logging: 7.403487920761108, 1, white, Exit
# Logging: 7.403487920761108, 4, white, Entry
# Logging: 7.403487920761108, 4, white, Exit
# Logging: 7.403487920761108, 3, white, Entry
# Logging: 7.403487920761108, 4, blue, Exit
# Logging: 7.403487920761108, 1, blue, Entry
# Logging: 7.403487920761108, 1, blue, Exit
# Logging: 7.403487920761108, 4, blue, Entry
# Logging: 7.480404615402222, 3, white, Exit
# Logging: 7.480404615402222, 1, white, Entry
# Logging: 7.480404615402222, 1, white, Exit
# Logging: 7.480404615402222, 4, white, Entry
# Logging: 7.480404615402222, 4, white, Exit
# Logging: 7.480404615402222, 3, white, Entry
# Logging: 7.480404615402222, 4, blue, Exit
# Logging: 7.480404615402222, 1, blue, Entry
# Logging: 7.480404615402222, 1, blue, Exit
# Logging: 7.480404615402222, 4, blue, Entry
# Logging: 7.562918663024902, 3, white, Exit
# Logging: 7.562918663024902, 2, white, Entry
# Logging: 7.562918663024902, 2, white, Exit
# Logging: 7.562918663024902, 1, white, Entry
# Logging: 7.562918663024902, 1, white, Exit
# Logging: 7.562918663024902, 4, white, Entry
# Logging: 7.562918663024902, 4, white, Exit
# Logging: 7.562918663024902, 3, white, Entry
# Logging: 7.562918663024902, 4, blue, Exit
# Logging: 7.562918663024902, 1, blue, Entry
# Logging: 7.562918663024902, 1, blue, Exit
# Logging: 7.562918663024902, 4, blue, Entry
# Logging: 7.648764610290527, 3, white, Exit
# Logging: 7.648764610290527, 2, white, Entry
# Logging: 7.648764610290527, 2, white, Exit
# Logging: 7.648764610290527, 1, white, Entry
# Logging: 7.648764610290527, 1, white, Exit
# Logging: 7.648764610290527, 3, white, Entry
# Logging: 7.648764610290527, 3, white, Exit
# Logging: 7.648764610290527, 4, white, Entry
# Logging: 7.648764610290527, 4, white, Exit
# Logging: 7.648764610290527, 3, white, Entry
# Logging: 7.648764610290527, 4, blue, Exit
# Logging: 7.648764610290527, 1, blue, Entry
# Logging: 7.648764610290527, 1, blue, Exit
# Logging: 7.648764610290527, 4, blue, Entry
# Logging: 7.734755754470825, 3, white, Exit
# Logging: 7.734755754470825, 2, white, Entry
# Logging: 7.734755754470825, 2, white, Exit
# Logging: 7.734755754470825, 1, white, Entry
# Logging: 7.734755754470825, 1, white, Exit
# Logging: 7.734755754470825, 4, white, Entry
# Logging: 7.734755754470825, 4, white, Exit
# Logging: 7.734755754470825, 3, white, Entry
# Logging: 7.734755754470825, 4, blue, Exit
# Logging: 7.734755754470825, 1, blue, Entry
# Logging: 7.734755754470825, 1, blue, Exit
# Logging: 7.734755754470825, 4, blue, Entry
# Logging: 7.805391073226929, 3, white, Exit
# Logging: 7.805391073226929, 2, white, Entry
# Logging: 7.805391073226929, 2, white, Exit
# Logging: 7.805391073226929, 1, white, Entry
# Logging: 7.805391073226929, 1, white, Exit
# Logging: 7.805391073226929, 4, white, Entry
# Logging: 7.805391073226929, 4, white, Exit
# Logging: 7.805391073226929, 3, white, Entry
# Logging: 7.805391073226929, 4, blue, Exit
# Logging: 7.805391073226929, 1, blue, Entry
# Logging: 7.805391073226929, 1, blue, Exit
# Logging: 7.805391073226929, 4, blue, Entry
# Logging: 7.894885540008545, 3, white, Exit
# Logging: 7.894885540008545, 2, white, Entry
# Logging: 7.894885540008545, 2, white, Exit
# Logging: 7.894885540008545, 1, white, Entry
# Logging: 7.894885540008545, 1, white, Exit
# Logging: 7.894885540008545, 2, white, Entry
# Logging: 7.894885540008545, 2, white, Exit
# Logging: 7.894885540008545, 1, white, Entry
# Logging: 7.894885540008545, 1, white, Exit
# Logging: 7.894885540008545, 2, white, Entry
# Logging: 7.894885540008545, 2, white, Exit
# Logging: 7.894885540008545, 4, white, Entry
# Logging: 7.894885540008545, 4, white, Exit
# Logging: 7.894885540008545, 3, white, Entry
# Logging: 7.894885540008545, 4, blue, Exit
# Logging: 7.894885540008545, 1, blue, Entry
# Logging: 7.894885540008545, 1, blue, Exit
# Logging: 7.894885540008545, 4, blue, Entry
# Logging: 7.986949920654297, 3, white, Exit
# Logging: 7.986949920654297, 2, white, Entry
# Logging: 7.986949920654297, 2, white, Exit
# Logging: 7.986949920654297, 1, white, Entry
# Logging: 7.986949920654297, 1, white, Exit
# Logging: 7.986949920654297, 2, white, Entry
# Logging: 7.986949920654297, 2, white, Exit
# Logging: 7.986949920654297, 1, white, Entry
# Logging: 7.986949920654297, 1, white, Exit
# Logging: 7.986949920654297, 2, white, Entry
# Logging: 7.986949920654297, 2, white, Exit
# Logging: 7.986949920654297, 4, white, Entry
# Logging: 7.986949920654297, 4, white, Exit
# Logging: 7.986949920654297, 3, white, Entry
# Logging: 7.986949920654297, 4, blue, Exit
# Logging: 7.986949920654297, 1, blue, Entry
# Logging: 7.986949920654297, 1, blue, Exit
# Logging: 7.986949920654297, 4, blue, Entry
# Logging: 8.07277250289917, 3, white, Exit
# Logging: 8.07277250289917, 2, white, Entry
# Logging: 8.07277250289917, 2, white, Exit
# Logging: 8.07277250289917, 1, white, Entry
# Logging: 8.07277250289917, 1, white, Exit
# Logging: 8.07277250289917, 2, white, Entry
# Logging: 8.07277250289917, 2, white, Exit
# Logging: 8.07277250289917, 1, white, Entry
# Logging: 8.07277250289917, 1, white, Exit
# Logging: 8.07277250289917, 2, white, Entry
# Logging: 8.07277250289917, 2, white, Exit
# Logging: 8.07277250289917, 3, white, Entry
# Logging: 8.07277250289917, 3, white, Exit
# Logging: 8.07277250289917, 4, white, Entry
# Logging: 8.07277250289917, 4, white, Exit
# Logging: 8.07277250289917, 3, white, Entry
# Logging: 8.07277250289917, 3, white, Exit
# Logging: 8.07277250289917, 4, white, Entry
# Logging: 8.07277250289917, 4, white, Exit
# Logging: 8.07277250289917, 3, white, Entry
# Logging: 8.07277250289917, 4, blue, Exit
# Logging: 8.07277250289917, 1, blue, Entry
# Logging: 8.07277250289917, 1, blue, Exit
# Logging: 8.07277250289917, 4, blue, Entry
# Logging: 8.154876232147217, 3, white, Exit
# Logging: 8.154876232147217, 2, white, Entry
# Logging: 8.154876232147217, 2, white, Exit
# Logging: 8.154876232147217, 1, white, Entry
# Logging: 8.154876232147217, 1, white, Exit
# Logging: 8.154876232147217, 2, white, Entry
# Logging: 8.154876232147217, 2, white, Exit
# Logging: 8.154876232147217, 4, white, Entry
# Logging: 8.154876232147217, 4, white, Exit
# Logging: 8.154876232147217, 3, white, Entry
# Logging: 8.154876232147217, 4, blue, Exit
# Logging: 8.154876232147217, 1, blue, Entry
# Logging: 8.154876232147217, 1, blue, Exit
# Logging: 8.154876232147217, 4, blue, Entry
# Logging: 8.2385094165802, 3, white, Exit
# Logging: 8.2385094165802, 2, white, Entry
# Logging: 8.2385094165802, 2, white, Exit
# Logging: 8.2385094165802, 1, white, Entry
# Logging: 8.2385094165802, 1, white, Exit
# Logging: 8.2385094165802, 2, white, Entry
# Logging: 8.2385094165802, 2, white, Exit
# Logging: 8.2385094165802, 1, white, Entry
# Logging: 8.2385094165802, 1, white, Exit
# Logging: 8.2385094165802, 4, white, Entry
# Logging: 8.2385094165802, 4, white, Exit
# Logging: 8.2385094165802, 3, white, Entry
# Logging: 8.2385094165802, 4, blue, Exit
# Logging: 8.2385094165802, 1, blue, Entry
# Logging: 8.2385094165802, 1, blue, Exit
# Logging: 8.2385094165802, 4, blue, Entry
# Logging: 8.321420669555664, 3, white, Exit
# Logging: 8.321420669555664, 1, white, Entry
# Logging: 8.321420669555664, 1, white, Exit
# Logging: 8.321420669555664, 2, white, Entry
# Logging: 8.321420669555664, 2, white, Exit
# Logging: 8.321420669555664, 1, white, Entry
# Logging: 8.321420669555664, 1, white, Exit
# Logging: 8.321420669555664, 2, white, Entry
# Logging: 8.321420669555664, 2, white, Exit
# Logging: 8.321420669555664, 1, white, Entry
# Logging: 8.321420669555664, 1, white, Exit
# Logging: 8.321420669555664, 4, white, Entry
# Logging: 8.321420669555664, 4, white, Exit
# Logging: 8.321420669555664, 3, white, Entry
# Logging: 8.321420669555664, 4, blue, Exit
# Logging: 8.321420669555664, 1, blue, Entry
# Logging: 8.321420669555664, 1, blue, Exit
# Logging: 8.321420669555664, 4, blue, Entry
# Logging: 8.402352094650269, 3, white, Exit
# Logging: 8.402352094650269, 1, white, Entry
# Logging: 8.402352094650269, 1, white, Exit
# Logging: 8.402352094650269, 2, white, Entry
# Logging: 8.402352094650269, 2, white, Exit
# Logging: 8.402352094650269, 1, white, Entry
# Logging: 8.402352094650269, 1, white, Exit
# Logging: 8.402352094650269, 2, white, Entry
# Logging: 8.402352094650269, 2, white, Exit
# Logging: 8.402352094650269, 1, white, Entry
# Logging: 8.402352094650269, 1, white, Exit
# Logging: 8.402352094650269, 3, white, Entry
# Logging: 8.402352094650269, 3, white, Exit
# Logging: 8.402352094650269, 4, white, Entry
# Logging: 8.402352094650269, 4, white, Exit
# Logging: 8.402352094650269, 3, white, Entry
# Logging: 8.402352094650269, 4, blue, Exit
# Logging: 8.402352094650269, 1, blue, Entry
# Logging: 8.402352094650269, 1, blue, Exit
# Logging: 8.402352094650269, 4, blue, Entry
# Logging: 8.48511815071106, 3, white, Exit
# Logging: 8.48511815071106, 1, white, Entry
# Logging: 8.48511815071106, 1, white, Exit
# Logging: 8.48511815071106, 2, white, Entry
# Logging: 8.48511815071106, 2, white, Exit
# Logging: 8.48511815071106, 1, white, Entry
# Logging: 8.48511815071106, 1, white, Exit
# Logging: 8.48511815071106, 2, white, Entry
# Logging: 8.48511815071106, 2, white, Exit
# Logging: 8.48511815071106, 1, white, Entry
# Logging: 8.48511815071106, 1, white, Exit
# Logging: 8.48511815071106, 2, white, Entry
# Logging: 8.48511815071106, 2, white, Exit
# Logging: 8.48511815071106, 1, white, Entry
# Logging: 8.48511815071106, 1, white, Exit
# Logging: 8.48511815071106, 2, white, Entry
# Logging: 8.48511815071106, 2, white, Exit
# Logging: 8.48511815071106, 1, white, Entry
# Logging: 8.48511815071106, 1, white, Exit
# Logging: 8.48511815071106, 3, white, Entry
# Logging: 8.48511815071106, 3, white, Exit
# Logging: 8.48511815071106, 4, white, Entry
# Logging: 8.48511815071106, 4, white, Exit
# Logging: 8.48511815071106, 3, white, Entry
# Logging: 8.48511815071106, 4, blue, Exit
# Logging: 8.48511815071106, 1, blue, Entry
# Logging: 8.48511815071106, 1, blue, Exit
# Logging: 8.48511815071106, 4, blue, Entry
# Logging: 8.570343255996704, 3, white, Exit
# Logging: 8.570343255996704, 1, white, Entry
# Logging: 8.570343255996704, 1, white, Exit
# Logging: 8.570343255996704, 2, white, Entry
# Logging: 8.570343255996704, 2, white, Exit
# Logging: 8.570343255996704, 1, white, Entry
# Logging: 8.570343255996704, 1, white, Exit
# Logging: 8.570343255996704, 2, white, Entry
# Logging: 8.570343255996704, 2, white, Exit
# Logging: 8.570343255996704, 4, white, Entry
# Logging: 8.570343255996704, 4, white, Exit
# Logging: 8.570343255996704, 3, white, Entry
# Logging: 8.570343255996704, 3, white, Exit
# Logging: 8.570343255996704, 4, white, Entry
# Logging: 8.570343255996704, 4, white, Exit
# Logging: 8.570343255996704, 3, white, Entry
# Logging: 8.570343255996704, 4, blue, Exit
# Logging: 8.570343255996704, 1, blue, Entry
# Logging: 8.570343255996704, 1, blue, Exit
# Logging: 8.570343255996704, 4, blue, Entry
# Logging: 8.655795097351074, 3, white, Exit
# Logging: 8.655795097351074, 1, white, Entry
# Logging: 8.655795097351074, 1, white, Exit
# Logging: 8.655795097351074, 2, white, Entry
# Logging: 8.655795097351074, 2, white, Exit
# Logging: 8.655795097351074, 1, white, Entry
# Logging: 8.655795097351074, 1, white, Exit
# Logging: 8.655795097351074, 4, white, Entry
# Logging: 8.655795097351074, 4, white, Exit
# Logging: 8.655795097351074, 3, white, Entry
# Logging: 8.655795097351074, 3, white, Exit
# Logging: 8.655795097351074, 4, white, Entry
# Logging: 8.655795097351074, 4, white, Exit
# Logging: 8.655795097351074, 3, white, Entry
# Logging: 8.655795097351074, 4, blue, Exit
# Logging: 8.655795097351074, 1, blue, Entry
# Logging: 8.655795097351074, 1, blue, Exit
# Logging: 8.655795097351074, 4, blue, Entry
# Logging: 8.733750343322754, 3, white, Exit
# Logging: 8.733750343322754, 1, white, Entry
# Logging: 8.733750343322754, 1, white, Exit
# Logging: 8.733750343322754, 2, white, Entry
# Logging: 8.733750343322754, 2, white, Exit
# Logging: 8.733750343322754, 1, white, Entry
# Logging: 8.733750343322754, 1, white, Exit
# Logging: 8.733750343322754, 4, white, Entry
# Logging: 8.733750343322754, 4, white, Exit
# Logging: 8.733750343322754, 3, white, Entry
# Logging: 8.733750343322754, 4, blue, Exit
# Logging: 8.733750343322754, 1, blue, Entry
# Logging: 8.733750343322754, 1, blue, Exit
# Logging: 8.733750343322754, 4, blue, Entry
# Logging: 8.816219568252563, 3, white, Exit
# Logging: 8.816219568252563, 2, white, Entry
# Logging: 8.816219568252563, 2, white, Exit
# Logging: 8.816219568252563, 1, white, Entry
# Logging: 8.816219568252563, 1, white, Exit
# Logging: 8.816219568252563, 4, white, Entry
# Logging: 8.816219568252563, 4, white, Exit
# Logging: 8.816219568252563, 3, white, Entry
# Logging: 8.816219568252563, 4, blue, Exit
# Logging: 8.816219568252563, 1, blue, Entry
# Logging: 8.816219568252563, 1, blue, Exit
# Logging: 8.816219568252563, 4, blue, Entry
# Logging: 8.894964456558228, 3, white, Exit
# Logging: 8.894964456558228, 2, white, Entry
# Logging: 8.894964456558228, 2, white, Exit
# Logging: 8.894964456558228, 1, white, Entry
# Logging: 8.894964456558228, 1, white, Exit
# Logging: 8.894964456558228, 4, white, Entry
# Logging: 8.894964456558228, 4, white, Exit
# Logging: 8.894964456558228, 3, white, Entry
# Logging: 8.894964456558228, 4, blue, Exit
# Logging: 8.894964456558228, 1, blue, Entry
# Logging: 8.894964456558228, 1, blue, Exit
# Logging: 8.894964456558228, 4, blue, Entry
# Logging: 8.967627048492432, 3, white, Exit
# Logging: 8.967627048492432, 2, white, Entry
# Logging: 8.967627048492432, 2, white, Exit
# Logging: 8.967627048492432, 1, white, Entry
# Logging: 8.967627048492432, 1, white, Exit
# Logging: 8.967627048492432, 4, white, Entry
# Logging: 8.967627048492432, 4, white, Exit
# Logging: 8.967627048492432, 3, white, Entry
# Logging: 8.967627048492432, 3, white, Exit
# Logging: 8.967627048492432, 4, white, Entry
# Logging: 8.967627048492432, 4, white, Exit
# Logging: 8.967627048492432, 3, white, Entry
# Logging: 8.967627048492432, 4, blue, Exit
# Logging: 8.967627048492432, 1, blue, Entry
# Logging: 8.967627048492432, 1, blue, Exit
# Logging: 8.967627048492432, 4, blue, Entry
# Logging: 9.048721313476562, 3, white, Exit
# Logging: 9.048721313476562, 2, white, Entry
# Logging: 9.048721313476562, 2, white, Exit
# Logging: 9.048721313476562, 1, white, Entry
# Logging: 9.048721313476562, 1, white, Exit
# Logging: 9.048721313476562, 4, white, Entry
# Logging: 9.048721313476562, 4, white, Exit
# Logging: 9.048721313476562, 3, white, Entry
# Logging: 9.048721313476562, 4, blue, Exit
# Logging: 9.048721313476562, 1, blue, Entry
# Logging: 9.048721313476562, 1, blue, Exit
# Logging: 9.048721313476562, 4, blue, Entry
# Logging: 9.131471633911133, 3, white, Exit
# Logging: 9.131471633911133, 2, white, Entry
# Logging: 9.131471633911133, 2, white, Exit
# Logging: 9.131471633911133, 1, white, Entry
# Logging: 9.131471633911133, 1, white, Exit
# Logging: 9.131471633911133, 4, white, Entry
# Logging: 9.131471633911133, 4, white, Exit
# Logging: 9.131471633911133, 3, white, Entry
# Logging: 9.131471633911133, 4, blue, Exit
# Logging: 9.131471633911133, 1, blue, Entry
# Logging: 9.131471633911133, 1, blue, Exit
# Logging: 9.131471633911133, 4, blue, Entry
# Logging: 9.226797819137573, 3, white, Exit
# Logging: 9.226797819137573, 2, white, Entry
# Logging: 9.226797819137573, 2, white, Exit
# Logging: 9.226797819137573, 1, white, Entry
# Logging: 9.226797819137573, 1, white, Exit
# Logging: 9.226797819137573, 4, white, Entry
# Logging: 9.226797819137573, 4, white, Exit
# Logging: 9.226797819137573, 3, white, Entry
# Logging: 9.226797819137573, 3, white, Exit
# Logging: 9.226797819137573, 4, white, Entry
# Logging: 9.226797819137573, 4, white, Exit
# Logging: 9.226797819137573, 3, white, Entry
# Logging: 9.226797819137573, 4, blue, Exit
# Logging: 9.226797819137573, 1, blue, Entry
# Logging: 9.226797819137573, 1, blue, Exit
# Logging: 9.226797819137573, 4, blue, Entry
# ...
# Logging: 267.914799451828, 4, blue, Entry
# Logging: 267.99031925201416, 4, white, Exit
# Logging: 267.99031925201416, 1, white, Entry
# Logging: 267.99031925201416, 1, white, Exit
# Logging: 267.99031925201416, 4, white, Entry
# Logging: 267.99031925201416, 4, white, Exit
# Logging: 267.99031925201416, 3, white, Entry
# Logging: 267.99031925201416, 3, white, Exit
# Logging: 267.99031925201416, 4, white, Entry
# Logging: 267.99031925201416, 4, blue, Exit
# Logging: 267.99031925201416, 1, blue, Entry
# Logging: 267.99031925201416, 1, blue, Exit
# Logging: 267.99031925201416, 4, blue, Entry
# Logging: 268.0672445297241, 4, white, Exit
# Logging: 268.0672445297241, 1, white, Entry
# Logging: 268.0672445297241, 1, white, Exit
# Logging: 268.0672445297241, 4, white, Entry
# Logging: 268.0672445297241, 4, white, Exit
# Logging: 268.0672445297241, 3, white, Entry
# Logging: 268.0672445297241, 3, white, Exit
# Logging: 268.0672445297241, 4, white, Entry
# Logging: 268.0672445297241, 4, white, Exit
# Logging: 268.0672445297241, 3, white, Entry
# Logging: 268.0672445297241, 3, white, Exit
# Logging: 268.0672445297241, 4, white, Entry
# Logging: 268.0672445297241, 4, blue, Exit
# Logging: 268.0672445297241, 1, blue, Entry
# Logging: 268.0672445297241, 1, blue, Exit
# Logging: 268.0672445297241, 4, blue, Entry
# Logging: 268.15908765792847, 4, white, Exit
# Logging: 268.15908765792847, 1, white, Entry
# Logging: 268.15908765792847, 1, white, Exit
# Logging: 268.15908765792847, 4, white, Entry
# Logging: 268.15908765792847, 4, white, Exit
# Logging: 268.15908765792847, 3, white, Entry
# Logging: 268.15908765792847, 3, white, Exit
# Logging: 268.15908765792847, 4, white, Entry
# Logging: 268.15908765792847, 4, blue, Exit
# Logging: 268.15908765792847, 1, blue, Entry
# Logging: 268.15908765792847, 1, blue, Exit
# Logging: 268.15908765792847, 4, blue, Entry
# Logging: 268.2318732738495, 4, white, Exit
# Logging: 268.2318732738495, 1, white, Entry
# Logging: 268.2318732738495, 1, white, Exit
# Logging: 268.2318732738495, 4, white, Entry
# Logging: 268.2318732738495, 4, white, Exit
# Logging: 268.2318732738495, 3, white, Entry
# Logging: 268.2318732738495, 3, white, Exit
# Logging: 268.2318732738495, 4, white, Entry
# Logging: 268.2318732738495, 4, blue, Exit
# Logging: 268.2318732738495, 1, blue, Entry
# Logging: 268.2318732738495, 1, blue, Exit
# Logging: 268.2318732738495, 4, blue, Entry
# Logging: 268.31113505363464, 4, white, Exit
# Logging: 268.31113505363464, 1, white, Entry
# Logging: 268.31113505363464, 1, white, Exit
# Logging: 268.31113505363464, 4, white, Entry
# Logging: 268.31113505363464, 4, white, Exit
# Logging: 268.31113505363464, 3, white, Entry
# Logging: 268.31113505363464, 3, white, Exit
# Logging: 268.31113505363464, 4, white, Entry
# Logging: 268.31113505363464, 4, blue, Exit
# Logging: 268.31113505363464, 1, blue, Entry
# Logging: 268.31113505363464, 1, blue, Exit
# Logging: 268.31113505363464, 4, blue, Entry
# Logging: 268.4031717777252, 4, white, Exit
# Logging: 268.4031717777252, 1, white, Entry
# Logging: 268.4031717777252, 1, white, Exit
# Logging: 268.4031717777252, 4, white, Entry
# Logging: 268.4031717777252, 4, white, Exit
# Logging: 268.4031717777252, 3, white, Entry
# Logging: 268.4031717777252, 4, blue, Exit
# Logging: 268.4031717777252, 1, blue, Entry
# Logging: 268.4031717777252, 1, blue, Exit
# Logging: 268.4031717777252, 4, blue, Entry
# Logging: 268.47859597206116, 3, white, Exit
# Logging: 268.47859597206116, 1, white, Entry
# Logging: 268.47859597206116, 1, white, Exit
# Logging: 268.47859597206116, 4, white, Entry
# Logging: 268.47859597206116, 4, white, Exit
# Logging: 268.47859597206116, 3, white, Entry
# Logging: 268.47859597206116, 4, blue, Exit
# Logging: 268.47859597206116, 1, blue, Entry
# Logging: 268.47859597206116, 1, blue, Exit
# Logging: 268.47859597206116, 4, blue, Entry
# Logging: 268.5882580280304, 3, white, Exit
# Logging: 268.5882580280304, 1, white, Entry
# Logging: 268.5882580280304, 1, white, Exit
# Logging: 268.5882580280304, 4, white, Entry
# Logging: 268.5882580280304, 4, white, Exit
# Logging: 268.5882580280304, 3, white, Entry
# Logging: 268.5882580280304, 3, white, Exit
# Logging: 268.5882580280304, 4, white, Entry
# Logging: 268.5882580280304, 4, blue, Exit
# Logging: 268.5882580280304, 1, blue, Entry
# Logging: 268.5882580280304, 1, blue, Exit
# Logging: 268.5882580280304, 4, blue, Entry
# Logging: 268.68018674850464, 4, white, Exit
# Logging: 268.68018674850464, 1, white, Entry
# Logging: 268.68018674850464, 1, white, Exit
# Logging: 268.68018674850464, 4, white, Entry
# Logging: 268.68018674850464, 4, white, Exit
# Logging: 268.68018674850464, 3, white, Entry
# Logging: 268.68018674850464, 3, white, Exit
# Logging: 268.68018674850464, 4, white, Entry
# Logging: 268.68018674850464, 4, blue, Exit
# Logging: 268.68018674850464, 1, blue, Entry
# Logging: 268.68018674850464, 1, blue, Exit
# Logging: 268.68018674850464, 4, blue, Entry
# Logging: 268.76776242256165, 4, white, Exit
# Logging: 268.76776242256165, 1, white, Entry
# Logging: 268.76776242256165, 1, white, Exit
# Logging: 268.76776242256165, 4, white, Entry
# Logging: 268.76776242256165, 4, white, Exit
# Logging: 268.76776242256165, 3, white, Entry
# Logging: 268.76776242256165, 4, blue, Exit
# Logging: 268.76776242256165, 1, blue, Entry
# Logging: 268.76776242256165, 1, blue, Exit
# Logging: 268.76776242256165, 4, blue, Entry
# Logging: 268.8512933254242, 3, white, Exit
# Logging: 268.8512933254242, 1, white, Entry
# Logging: 268.8512933254242, 1, white, Exit
# Logging: 268.8512933254242, 4, white, Entry
# Logging: 268.8512933254242, 4, white, Exit
# Logging: 268.8512933254242, 3, white, Entry
# Logging: 268.8512933254242, 4, blue, Exit
# Logging: 268.8512933254242, 1, blue, Entry
# Logging: 268.8512933254242, 1, blue, Exit
# Logging: 268.8512933254242, 4, blue, Entry
# Logging: 268.94316005706787, 3, white, Exit
# Logging: 268.94316005706787, 1, white, Entry
# Logging: 268.94316005706787, 1, white, Exit
# Logging: 268.94316005706787, 4, white, Entry
# Logging: 268.94316005706787, 4, white, Exit
# Logging: 268.94316005706787, 3, white, Entry
# Logging: 268.94316005706787, 4, blue, Exit
# Logging: 268.94316005706787, 1, blue, Entry
# Logging: 268.94316005706787, 1, blue, Exit
# Logging: 268.94316005706787, 4, blue, Entry
# Logging: 269.01763558387756, 3, white, Exit
# Logging: 269.01763558387756, 1, white, Entry
# Logging: 269.01763558387756, 1, white, Exit
# Logging: 269.01763558387756, 4, white, Entry
# Logging: 269.01763558387756, 4, white, Exit
# Logging: 269.01763558387756, 3, white, Entry
# Logging: 269.01763558387756, 3, white, Exit
# Logging: 269.01763558387756, 4, white, Entry
# Logging: 269.01763558387756, 4, blue, Exit
# Logging: 269.01763558387756, 1, blue, Entry
# Logging: 269.01763558387756, 1, blue, Exit
# Logging: 269.01763558387756, 4, blue, Entry
# Logging: 269.093772649765, 4, white, Exit
# Logging: 269.093772649765, 1, white, Entry
# Logging: 269.093772649765, 1, white, Exit
# Logging: 269.093772649765, 4, white, Entry
# Logging: 269.093772649765, 4, white, Exit
# Logging: 269.093772649765, 3, white, Entry
# Logging: 269.093772649765, 3, white, Exit
# Logging: 269.093772649765, 4, white, Entry
# Logging: 269.093772649765, 4, blue, Exit
# Logging: 269.093772649765, 1, blue, Entry
# Logging: 269.093772649765, 1, blue, Exit
# Logging: 269.093772649765, 4, blue, Entry
# Logging: 269.1743941307068, 4, white, Exit
# Logging: 269.1743941307068, 1, white, Entry
# Logging: 269.1743941307068, 1, white, Exit
# Logging: 269.1743941307068, 4, white, Entry
# Logging: 269.1743941307068, 4, white, Exit
# Logging: 269.1743941307068, 3, white, Entry
# Logging: 269.1743941307068, 3, white, Exit
# Logging: 269.1743941307068, 4, white, Entry
# Logging: 269.1743941307068, 4, blue, Exit
# Logging: 269.1743941307068, 1, blue, Entry
# Logging: 269.1743941307068, 1, blue, Exit
# Logging: 269.1743941307068, 4, blue, Entry
# Logging: 269.24919390678406, 4, white, Exit
# Logging: 269.24919390678406, 1, white, Entry
# Logging: 269.24919390678406, 1, white, Exit
# Logging: 269.24919390678406, 4, white, Entry
# Logging: 269.24919390678406, 4, white, Exit
# Logging: 269.24919390678406, 3, white, Entry
# Logging: 269.24919390678406, 3, white, Exit
# Logging: 269.24919390678406, 4, white, Entry
# Logging: 269.24919390678406, 4, blue, Exit
# Logging: 269.24919390678406, 1, blue, Entry
# Logging: 269.24919390678406, 1, blue, Exit
# Logging: 269.24919390678406, 4, blue, Entry
# Logging: 269.334107875824, 4, white, Exit
# Logging: 269.334107875824, 1, white, Entry
# Logging: 269.334107875824, 1, white, Exit
# Logging: 269.334107875824, 4, white, Entry
# Logging: 269.334107875824, 4, white, Exit
# Logging: 269.334107875824, 3, white, Entry
# Logging: 269.334107875824, 3, white, Exit
# Logging: 269.334107875824, 4, white, Entry
# Logging: 269.334107875824, 4, blue, Exit
# Logging: 269.334107875824, 1, blue, Entry
# Logging: 269.334107875824, 1, blue, Exit
# Logging: 269.334107875824, 4, blue, Entry
# Logging: 269.45648097991943, 4, white, Exit
# Logging: 269.45648097991943, 1, white, Entry
# Logging: 269.45648097991943, 1, white, Exit
# Logging: 269.45648097991943, 4, white, Entry
# Logging: 269.45648097991943, 4, white, Exit
# Logging: 269.45648097991943, 3, white, Entry
# Logging: 269.45648097991943, 3, white, Exit
# Logging: 269.45648097991943, 4, white, Entry
# Logging: 269.45648097991943, 4, blue, Exit
# Logging: 269.45648097991943, 1, blue, Entry
# Logging: 269.45648097991943, 1, blue, Exit
# Logging: 269.45648097991943, 4, blue, Entry
# Logging: 269.54863476753235, 4, white, Exit
# Logging: 269.54863476753235, 1, white, Entry
# Logging: 269.54863476753235, 1, white, Exit
# Logging: 269.54863476753235, 4, white, Entry
# Logging: 269.54863476753235, 4, white, Exit
# Logging: 269.54863476753235, 3, white, Entry
# Logging: 269.54863476753235, 3, white, Exit
# Logging: 269.54863476753235, 4, white, Entry
# Logging: 269.54863476753235, 4, blue, Exit
# Logging: 269.54863476753235, 1, blue, Entry
# Logging: 269.54863476753235, 1, blue, Exit
# Logging: 269.54863476753235, 4, blue, Entry
# Logging: 269.6410574913025, 4, white, Exit
# Logging: 269.6410574913025, 1, white, Entry
# Logging: 269.6410574913025, 1, white, Exit
# Logging: 269.6410574913025, 4, white, Entry
# Logging: 269.6410574913025, 4, white, Exit
# Logging: 269.6410574913025, 3, white, Entry
# Logging: 269.6410574913025, 3, white, Exit
# Logging: 269.6410574913025, 4, white, Entry
# Logging: 269.6410574913025, 4, blue, Exit
# Logging: 269.6410574913025, 1, blue, Entry
# Logging: 269.6410574913025, 1, blue, Exit
# Logging: 269.6410574913025, 4, blue, Entry
# Logging: 269.71531796455383, 4, white, Exit
# Logging: 269.71531796455383, 1, white, Entry
# Logging: 269.71531796455383, 1, white, Exit
# Logging: 269.71531796455383, 4, white, Entry
# Logging: 269.71531796455383, 4, white, Exit
# Logging: 269.71531796455383, 3, white, Entry
# Logging: 269.71531796455383, 3, white, Exit
# Logging: 269.71531796455383, 4, white, Entry
# Logging: 269.71531796455383, 4, blue, Exit
# Logging: 269.71531796455383, 1, blue, Entry
# Logging: 269.71531796455383, 1, blue, Exit
# Logging: 269.71531796455383, 4, blue, Entry
# Logging: 269.7800886631012, 4, white, Exit
# Logging: 269.7800886631012, 1, white, Entry
# Logging: 269.7800886631012, 1, white, Exit
# Logging: 269.7800886631012, 4, white, Entry
# Logging: 269.7800886631012, 4, white, Exit
# Logging: 269.7800886631012, 3, white, Entry
# Logging: 269.7800886631012, 3, white, Exit
# Logging: 269.7800886631012, 4, white, Entry
# Logging: 269.7800886631012, 4, blue, Exit
# Logging: 269.7800886631012, 1, blue, Entry
# Logging: 269.7800886631012, 1, blue, Exit
# Logging: 269.7800886631012, 4, blue, Entry
# Logging: 269.8584804534912, 4, white, Exit
# Logging: 269.8584804534912, 1, white, Entry
# Logging: 269.8584804534912, 1, white, Exit
# Logging: 269.8584804534912, 4, white, Entry
# Logging: 269.8584804534912, 4, white, Exit
# Logging: 269.8584804534912, 3, white, Entry
# Logging: 269.8584804534912, 3, white, Exit
# Logging: 269.8584804534912, 4, white, Entry
# Logging: 269.8584804534912, 4, blue, Exit
# Logging: 269.8584804534912, 1, blue, Entry
# Logging: 269.8584804534912, 1, blue, Exit
# Logging: 269.8584804534912, 4, blue, Entry
# Logging: 269.9322347640991, 4, white, Exit
# Logging: 269.9322347640991, 1, white, Entry
# Logging: 269.9322347640991, 1, white, Exit
# Logging: 269.9322347640991, 4, white, Entry
# Logging: 269.9322347640991, 4, white, Exit
# Logging: 269.9322347640991, 3, white, Entry
# Logging: 269.9322347640991, 3, white, Exit
# Logging: 269.9322347640991, 4, white, Entry
# Logging: 269.9322347640991, 4, blue, Exit
# Logging: 269.9322347640991, 1, blue, Entry
# Logging: 269.9322347640991, 1, blue, Exit
# Logging: 269.9322347640991, 4, blue, Entry
# Logging: 269.99534797668457, 4, white, Exit
# Logging: 269.99534797668457, 1, white, Entry
# Logging: 269.99534797668457, 1, white, Exit
# Logging: 269.99534797668457, 4, white, Entry
# Logging: 269.99534797668457, 4, white, Exit
# Logging: 269.99534797668457, 3, white, Entry
# Logging: 269.99534797668457, 3, white, Exit
# Logging: 269.99534797668457, 4, white, Entry
# Logging: 269.99534797668457, 4, blue, Exit
# Logging: 269.99534797668457, 1, blue, Entry
# Logging: 269.99534797668457, 1, blue, Exit
# Logging: 269.99534797668457, 4, blue, Entry
# Logging: 270.0736668109894, 4, white, Exit
# Logging: 270.0736668109894, 1, white, Entry
# Logging: 270.0736668109894, 1, white, Exit
# Logging: 270.0736668109894, 4, white, Entry
# Logging: 270.0736668109894, 4, white, Exit
# Logging: 270.0736668109894, 3, white, Entry
# Logging: 270.0736668109894, 3, white, Exit
# Logging: 270.0736668109894, 4, white, Entry
# Logging: 270.0736668109894, 4, blue, Exit
# Logging: 270.0736668109894, 1, blue, Entry
# Logging: 270.0736668109894, 1, blue, Exit
# Logging: 270.0736668109894, 4, blue, Entry
# Logging: 270.16561579704285, 4, white, Exit
# Logging: 270.16561579704285, 1, white, Entry
# Logging: 270.16561579704285, 1, white, Exit
# Logging: 270.16561579704285, 4, white, Entry
# Logging: 270.16561579704285, 4, white, Exit
# Logging: 270.16561579704285, 3, white, Entry
# Logging: 270.16561579704285, 3, white, Exit
# Logging: 270.16561579704285, 4, white, Entry
# Logging: 270.16561579704285, 4, blue, Exit
# Logging: 270.16561579704285, 1, blue, Entry
# Logging: 270.16561579704285, 1, blue, Exit
# Logging: 270.16561579704285, 4, blue, Entry
# Logging: 270.2607522010803, 4, white, Exit
# Logging: 270.2607522010803, 1, white, Entry
# Logging: 270.2607522010803, 1, white, Exit
# Logging: 270.2607522010803, 4, white, Entry
# Logging: 270.2607522010803, 4, white, Exit
# Logging: 270.2607522010803, 3, white, Entry
# Logging: 270.2607522010803, 3, white, Exit
# Logging: 270.2607522010803, 4, white, Entry
# Logging: 270.2607522010803, 4, blue, Exit
# Logging: 270.2607522010803, 1, blue, Entry
# Logging: 270.2607522010803, 1, blue, Exit
# Logging: 270.2607522010803, 4, blue, Entry
# Logging: 270.3481729030609, 4, white, Exit
# Logging: 270.3481729030609, 1, white, Entry
# Logging: 270.3481729030609, 1, white, Exit
# Logging: 270.3481729030609, 4, white, Entry
# Logging: 270.3481729030609, 4, white, Exit
# Logging: 270.3481729030609, 3, white, Entry
# Logging: 270.3481729030609, 3, white, Exit
# Logging: 270.3481729030609, 4, white, Entry
# Logging: 270.3481729030609, 4, blue, Exit
# Logging: 270.3481729030609, 1, blue, Entry
# Logging: 270.3481729030609, 1, blue, Exit
# Logging: 270.3481729030609, 4, blue, Entry
# Logging: 270.4288959503174, 4, white, Exit
# Logging: 270.4288959503174, 1, white, Entry
# Logging: 270.4288959503174, 1, white, Exit
# Logging: 270.4288959503174, 4, white, Entry
# Logging: 270.4288959503174, 4, white, Exit
# Logging: 270.4288959503174, 3, white, Entry
# Logging: 270.4288959503174, 3, white, Exit
# Logging: 270.4288959503174, 4, white, Entry
# Logging: 270.4288959503174, 4, blue, Exit
# Logging: 270.4288959503174, 1, blue, Entry
# Logging: 270.4288959503174, 1, blue, Exit
# Logging: 270.4288959503174, 4, blue, Entry
# Logging: 270.50538182258606, 4, white, Exit
# Logging: 270.50538182258606, 1, white, Entry
# Logging: 270.50538182258606, 1, white, Exit
# Logging: 270.50538182258606, 4, white, Entry
# Logging: 270.50538182258606, 4, white, Exit
# Logging: 270.50538182258606, 3, white, Entry
# Logging: 270.50538182258606, 4, blue, Exit
# Logging: 270.50538182258606, 1, blue, Entry
# Logging: 270.50538182258606, 1, blue, Exit
# Logging: 270.50538182258606, 4, blue, Entry
# Processed video saved as: processed_video.mp4
# Event log saved as: event_log.csv
